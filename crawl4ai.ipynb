# %%
import asyncio
from crawl4ai import AsyncWebCrawler

async def main():
    async with AsyncWebCrawler(verbose=True) as crawler:
        result = await crawler.arun(url="https://espndeportes.espn.com/")
        print(result.markdown)

await main()
# Out:
# [LOG] 🌤️  Warming up the AsyncWebCrawler
# [LOG] 🌞 AsyncWebCrawler is ready to crawl
# [LOG] 🕸️ Crawling https://espndeportes.espn.com/ using AsyncPlaywrightCrawlerStrategy...
# [LOG] ✅ Crawled https://espndeportes.espn.com/ successfully!
# [LOG] 🚀 Crawling done for https://espndeportes.espn.com/, success: True, time taken: 1.74 seconds
# [LOG] 🚀 Content extracted for https://espndeportes.espn.com/, success: True, time taken: 0.09 seconds
# [LOG] 🔥 Extracting semantic blocks for https://espndeportes.espn.com/, Strategy: AsyncWebCrawler
# [LOG] 🚀 Extraction done for https://espndeportes.espn.com/, time taken: 0.09 seconds.
# Salta al contenido principal  Ir a la navegación
#
# <
#
# >
#
# Menu
#
# ## ESPN
#
#   *   * Resultados
#
# Has llegado a la edición de ESPN Deportes. Quedarse en el sitio actual o ir a
# edición preferida.
#
#   * Fútbol
#   * F. Americano
#   * MLB
#   * Básquetbol
#   * F1
#   * Boxeo
#   * MMA
#   * Más Deportes
#
#     * Tenis
#     * esports
# ...
